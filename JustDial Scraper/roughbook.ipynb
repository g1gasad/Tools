# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
import time 

path = "E:\Projects\Automations\WEBDRIVER\chromedriver.exe"

option = webdriver.ChromeOptions()
option.add_argument("user-data-dir=C:/Users/CWC/AppData/Local/Google/Chrome/User Data")

service = Service(executable_path=path)
driver = webdriver.Chrome(service=service, options=option)

driver.get("https://wap.justdial.com/analytics/enquiries?el=0&nh=1&rootvc=0&docid=9999PX771.X771.150630125848.H5Q6&hide_header=1&m=1&mobile=8390005813&old=1&source=77&tab=enquiries&wap=77&tab=enquiries")

height = driver.execute_script("return document.body.scrollHeight")
# print(height)
i = 0
while i != 2:
    containers = driver.find_elements(by='xpath', value='//div[@class="lead_slide lead_slide--missed p-15"]')
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(3)
    i += 1

print(len(containers))

titles = []
locations = []
date_times = []
descriptions = []
sources = []
names = []

for container in containers:
    title = container.find_element(by='xpath', value='//div[@class="lead_slide lead_slide--missed p-15"]//div[@class="lead_slide_infobig font15 fw600 color414"]').text
    location = container.find_element(by='xpath', value='//div[@class="lead_slide lead_slide--missed p-15"]//span[@class="infosml_loct fw700"]').text
    date_time = container.find_element(by='xpath', value='//div[@class="lead_slide lead_slide--missed p-15"]//span[@class="infosml_time"]').text
    description = container.find_element(by='xpath', value='//div[@class="lead_slide lead_slide--missed p-15"]//div[@class="lead_slide_descr_text pb-10 font13 fw400 color414"]').text
    source = container.find_element(by='xpath', value='//div[@class="lead_slide lead_slide--missed p-15"]//div[@class="userinfo_name font13 fw600 color414 mb-10"]').text
    name = container.find_element(by='xpath', value='//div[@class="lead_slide lead_slide--missed p-15"]//div[@class="userinfo_name font13 fw600 color414"]').text
    # source = container.find_element(by='xpath', value='.//div[@class="userinfo_name font13 fw600 color414 mb-10"]').text
    titles.append(title)
    locations.append(location)
    date_times.append(date_time)
    descriptions.append(description)
    sources.append(source)
    names.append(name)
    
df = pd.DataFrame(
                {
                    'Title': titles,
                    'Location': locations,
                    'Date and Time': date_times,
                    'Description': descriptions,
                    'Source': sources,
                    'Name': names
            }
)

driver.quit()
# Out:
# 38

# %%
containers
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_91")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_92")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_93")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_94")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_95")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_97")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_98")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_99")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_100")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_101")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_102")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_103")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_104")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_105")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_106")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_107")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_108")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_109")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_110")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_111")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_112")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_113")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_114")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_115")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_116")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_117")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_118")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_119")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_120")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_121")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_122")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_123")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_124")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_125")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_126")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d32c728e81b1a3fbeb6f68e5b4fbfe82", element="87E581FD4F0BDA91F91CB2F19D4FF67D_element_127")>]

# %%
# /html/body/div/div/div/div/div/div/section[2]/div/div[2]/div/div/div
# /html/body/div/div/div/div/div/div/section[2]/div/div[3]/div/div[1]/div
# /html/body/div/div/div/div/div/div/section[2]/div/div[3]/div/div[2]/div
# /html/body/div/div/div/div/div/div/section[2]/div/div[4]/div/div[1]/div
containers
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5dadd5bf4a6c4c61e0e0c8a6ecb90e76", element="819ECC39F48408E372320F2BEB2AC424_element_86")>

# %%
print(containers[0])
print(containers[1])
print(containers[2])
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="194e9a4806458d1a3f12f19c6dd2f975", element="EEACE6FC9B2C65891C393D5889A3EDAF_element_192")>
# <selenium.webdriver.remote.webelement.WebElement (session="194e9a4806458d1a3f12f19c6dd2f975", element="EEACE6FC9B2C65891C393D5889A3EDAF_element_193")>
# <selenium.webdriver.remote.webelement.WebElement (session="194e9a4806458d1a3f12f19c6dd2f975", element="EEACE6FC9B2C65891C393D5889A3EDAF_element_194")>

# %%
df
# Out:
#              Title             Location          Date and Time  \
# 0   Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 1   Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 2   Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 3   Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 4   Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 5   Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 6   Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 7   Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 8   Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 9   Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 10  Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 11  Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 12  Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 13  Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 14  Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 15  Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 16  Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
# 17  Land Surveyors  Raipur-chhattisgarh  21 Nov 2023, 11:29 am
#
#                              Description                Source     Name
# 0   Koushik searched for land surveyors.  Category Search Lead  Koushik
# 1   Koushik searched for land surveyors.  Category Search Lead  Koushik
# 2   Koushik searched for land surveyors.  Category Search Lead  Koushik
# 3   Koushik searched for land surveyors.  Category Search Lead  Koushik
# 4   Koushik searched for land surveyors.  Category Search Lead  Koushik
# 5   Koushik searched for land surveyors.  Category Search Lead  Koushik
# 6   Koushik searched for land surveyors.  Category Search Lead  Koushik
# 7   Koushik searched for land surveyors.  Category Search Lead  Koushik
# 8   Koushik searched for land surveyors.  Category Search Lead  Koushik
# 9   Koushik searched for land surveyors.  Category Search Lead  Koushik
# 10  Koushik searched for land surveyors.  Category Search Lead  Koushik
# 11  Koushik searched for land surveyors.  Category Search Lead  Koushik
# 12  Koushik searched for land surveyors.  Category Search Lead  Koushik
# 13  Koushik searched for land surveyors.  Category Search Lead  Koushik
# 14  Koushik searched for land surveyors.  Category Search Lead  Koushik
# 15  Koushik searched for land surveyors.  Category Search Lead  Koushik
# 16  Koushik searched for land surveyors.  Category Search Lead  Koushik
# 17  Koushik searched for land surveyors.  Category Search Lead  Koushik
