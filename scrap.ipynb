# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
np.arange(4)
# Out:
# array([0, 1, 2, 3])

# %%
x_cords = range(0,50)
y_cords = [x*x for x in x_cords]

plt.plot(x_cords, y_cords, '-o')
plt.show()
